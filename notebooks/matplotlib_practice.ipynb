# %% [markdown]
# ## Matplotlib - Data visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)

# %%
fig, ax = plt.subplots()
ax.bar(["a", "b", "c"], [3, 7, 5])
# Out:
# <BarContainer object of 3 artists>

# %%
data = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(data, bins=30)
# Out:
# (array([ 1.,  1.,  0.,  8.,  8.,  8., 20., 21., 27., 40., 40., 61., 69.,
#         74., 76., 72., 86., 86., 73., 64., 43., 37., 37., 14.,  7., 12.,
#          6.,  5.,  2.,  2.]),
#  array([-3.14840589, -2.94176725, -2.7351286 , -2.52848996, -2.32185132,
#         -2.11521267, -1.90857403, -1.70193539, -1.49529675, -1.2886581 ,
#         -1.08201946, -0.87538082, -0.66874217, -0.46210353, -0.25546489,
#         -0.04882625,  0.1578124 ,  0.36445104,  0.57108968,  0.77772833,
#          0.98436697,  1.19100561,  1.39764425,  1.6042829 ,  1.81092154,
#          2.01756018,  2.22419883,  2.43083747,  2.63747611,  2.84411475,
#          3.0507534 ]),
#  <BarContainer object of 30 artists>)

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label="sin(x)")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("Sine Wave")
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), label="sin")
ax.plot(x, np.cos(x), label="cos")
ax.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
axes[0].plot(x, np.sin(x))
axes[0].set_title("sin")
axes[1].plot(x, np.cos(x))
axes[1].set_title("cos")
fig.tight_layout()
